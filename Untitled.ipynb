# %%
df = pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  __year_resale_value Vehicle_type  Engine_size  \
# 0          Acura  Integra               16.360    Passenger          1.8
# 1          Acura       TL               19.875    Passenger          3.2
# 2          Acura       CL               18.225    Passenger          3.2
# 3          Acura       RL               29.725    Passenger          3.5
# 4           Audi       A4               22.255    Passenger          1.8
# ..           ...      ...                  ...          ...          ...
# 152        Volvo      V40                  NaN    Passenger          1.9
# 153        Volvo      S70                  NaN    Passenger          2.4
# 154        Volvo      V70                  NaN    Passenger          2.4
# 155        Volvo      C70                  NaN    Passenger          2.3
# 156        Volvo      S80                  NaN    Passenger          2.9
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# __year_resale_value    36
# Vehicle_type            0
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# Sales_in_thousands      0
# Price_in_thousands      2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   __year_resale_value  121 non-null    float64
#  3   Vehicle_type         157 non-null    object
#  4   Engine_size          156 non-null    float64
#  5   Horsepower           156 non-null    float64
#  6   Wheelbase            156 non-null    float64
#  7   Width                156 non-null    float64
#  8   Length               156 non-null    float64
#  9   Curb_weight          155 non-null    float64
#  10  Fuel_capacity        156 non-null    float64
#  11  Fuel_efficiency      154 non-null    float64
#  12  Latest_Launch        157 non-null    object
#  13  Power_perf_factor    155 non-null    float64
#  14  Sales_in_thousands   157 non-null    float64
# ...

# %%
df['Latest_Launch'] = pd.to_datetime(df['Latest_Launch'])

df['Launch_Year'] = (df['Latest_Launch']).dt.year

# %%
df = df.drop(['__year_resale_value', 'Latest_Launch'], axis =1 )
df = df.dropna()
df
# Out:
#     Manufacturer    Model Vehicle_type  Engine_size  Horsepower  Wheelbase  \
# 0          Acura  Integra    Passenger          1.8       140.0      101.2
# 1          Acura       TL    Passenger          3.2       225.0      108.1
# 3          Acura       RL    Passenger          3.5       210.0      114.6
# 4           Audi       A4    Passenger          1.8       150.0      102.6
# 5           Audi       A6    Passenger          2.8       200.0      108.7
# ..           ...      ...          ...          ...         ...        ...
# 152        Volvo      V40    Passenger          1.9       160.0      100.5
# 153        Volvo      S70    Passenger          2.4       168.0      104.9
# 154        Volvo      V70    Passenger          2.4       168.0      104.9
# 155        Volvo      C70    Passenger          2.3       236.0      104.9
# 156        Volvo      S80    Passenger          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Vehicle_type', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Power_perf_factor', 'Sales_in_thousands',
#        'Price_in_thousands', 'Launch_Year'],
#       dtype='object')

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#      Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0            1.8       140.0      101.2   67.3   172.4        2.639
# 1            3.2       225.0      108.1   70.3   192.9        3.517
# 3            3.5       210.0      114.6   71.4   196.6        3.850
# 4            1.8       150.0      102.6   68.2   178.0        2.998
# 5            2.8       200.0      108.7   76.1   192.0        3.561
# ..           ...         ...        ...    ...     ...          ...
# 152          1.9       160.0      100.5   67.6   176.6        3.042
# 153          2.4       168.0      104.9   69.3   185.9        3.208
# 154          2.4       168.0      104.9   69.3   186.2        3.259
# 155          2.3       236.0      104.9   71.5   185.7        3.601
# 156          2.9       201.0      109.9   72.1   189.8        3.600
#
#      Fuel_capacity  Fuel_efficiency  Power_perf_factor  Sales_in_thousands  \
# ...

# %%
def corre(df, thre):
    corr_cols = set()
    corr = df.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > thre:
                cols = corr.columns[i]
                corr_cols.add(cols)
                
    return corr_cols

corre(df_dummies, 0.8)
# Out:
# {'Fuel_capacity',
#  'Fuel_efficiency',
#  'Horsepower',
#  'Length',
#  'Model_I30',
#  'Model_S-Type',
#  'Power_perf_factor',
#  'Price_in_thousands',
#  'Vehicle_type_Passenger'}

# %%
y = df_dummies['Price_in_thousands']
df_x = df_dummies.drop(['Price_in_thousands'], axis =1)

# %%
from sklearn.preprocessing import StandardScaler

stand =  StandardScaler()

stand_df = stand.fit_transform(df_x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.75)
red = pca.fit_transform(stand_df)
red.shape
# Out:
# (152, 102)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(red, y, test_size= 0.3, random_state= 42)

# %%
from sklearn.linear_model import LinearRegression

regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(x_test)

# %%
from sklearn import metrics
rmse = metrics.root_mean_squared_error(pred, y_test)
print (rmse)
# Out:
# 0.4423871065869698

# %%
df['Price_in_thousands'].idxmin()
# Out:
# 26

# %%
relative_error = (rmse / y.mean()) * 100
print(f"Relative Error: {relative_error:.2f}%")
# Out:
# Relative Error: 1.62%
