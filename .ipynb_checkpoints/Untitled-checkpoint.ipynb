# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  __year_resale_value Vehicle_type  Engine_size  \
# 0          Acura  Integra               16.360    Passenger          1.8
# 1          Acura       TL               19.875    Passenger          3.2
# 2          Acura       CL               18.225    Passenger          3.2
# 3          Acura       RL               29.725    Passenger          3.5
# 4           Audi       A4               22.255    Passenger          1.8
# ..           ...      ...                  ...          ...          ...
# 152        Volvo      V40                  NaN    Passenger          1.9
# 153        Volvo      S70                  NaN    Passenger          2.4
# 154        Volvo      V70                  NaN    Passenger          2.4
# 155        Volvo      C70                  NaN    Passenger          2.3
# 156        Volvo      S80                  NaN    Passenger          2.9
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# __year_resale_value    36
# Vehicle_type            0
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# Sales_in_thousands      0
# Price_in_thousands      2
# dtype: int64

# %%
df = df.drop(['__year_resale_value'], axis =1 )

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (152, 15)

# %%
df
# Out:
#     Manufacturer    Model Vehicle_type  Engine_size  Horsepower  Wheelbase  \
# 0          Acura  Integra    Passenger          1.8       140.0      101.2
# 1          Acura       TL    Passenger          3.2       225.0      108.1
# 3          Acura       RL    Passenger          3.5       210.0      114.6
# 4           Audi       A4    Passenger          1.8       150.0      102.6
# 5           Audi       A6    Passenger          2.8       200.0      108.7
# ..           ...      ...          ...          ...         ...        ...
# 152        Volvo      V40    Passenger          1.9       160.0      100.5
# 153        Volvo      S70    Passenger          2.4       168.0      104.9
# 154        Volvo      V70    Passenger          2.4       168.0      104.9
# 155        Volvo      C70    Passenger          2.3       236.0      104.9
# 156        Volvo      S80    Passenger          2.9       201.0      109.9
#
# ...

# %%
def corre(df, thre):
    corr_cols = set()
    corr = df.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > thre:
                cols = corr.columns[i]
                corr_cols.add(cols)
                
    return corr_cols

corre(df, 0.8)
# Out:
# C:\Users\KoDaKs\AppData\Local\Temp\ipykernel_6184\2556678447.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# {'Fuel_capacity',
#  'Fuel_efficiency',
#  'Horsepower',
#  'Length',
#  'Power_perf_factor',
#  'Price_in_thousands'}

# %%
df.Vehicle_type.value_counts()
# Out:
# Passenger    112
# Car           40
# Name: Vehicle_type, dtype: int64

# %%
x = df.drop(['Price_in_thousands', 'Latest_Launch', 'Fuel_capacity',
 'Fuel_efficiency',
 'Horsepower',
 'Length',
 'Power_perf_factor'], axis = 1)
y = df['Price_in_thousands']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.3)

# %%
x_test
# Out:
#     Manufacturer         Model Vehicle_type  Engine_size  Wheelbase  Width  \
# 34      Chrysler          300M    Passenger          3.5      113.0   74.4
# 13         Buick       LeSabre    Passenger          3.8      112.2   73.5
# 26     Chevrolet         Metro    Passenger          1.0       93.1   62.6
# 137       Toyota         Camry    Passenger          2.2      105.2   70.1
# 74         Lexus         LX470          Car          4.7      112.2   76.4
# 57         Honda         Civic    Passenger          1.6      103.2   67.1
# 142       Toyota          RAV4          Car          2.0       94.9   66.7
# 102       Nissan        Altima    Passenger          2.4      103.1   69.1
# 150   Volkswagen        Beetle    Passenger          2.0       98.9   67.9
# 19     Chevrolet      Cavalier    Passenger          2.2      104.1   67.9
# 98    Mercedes-B     CLK Coupe    Passenger          3.2      105.9   67.8
# ...

# %%
x_test[['Manufacturer', 'Model', 'Vehicle_type']] = x_test[['Manufacturer', 'Model', 'Vehicle_type']].apply(LabelEncoder().fit_transform)

# %%
x_train[['Manufacturer', 'Model', 'Vehicle_type']] = x_train[['Manufacturer', 'Model', 'Vehicle_type']].apply(LabelEncoder().fit_transform)

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(x_test)

# %%
pred
# Out:
# array([31.20198117, 31.3703392 ,  9.08577105, 11.33977364, 54.13004806,
#         2.44292513, 14.68651018, 22.46151158, 22.17204771, 12.55894286,
#        33.4360002 , 34.72744597, 18.72538841, 17.70122328,  7.7981177 ,
#        17.33644447, 29.35935143, 19.55538371, 16.40338651, 15.65831104,
#        23.34934458, 32.33308171, 40.97576902, 51.50168072, 31.81655482,
#        -5.7743134 , 40.35257746, 26.94687526,  0.4375747 , 16.2888225 ,
#        20.33366036, 32.13893488, 34.53449738, 23.74668575, 15.26482648,
#        16.42430738, 33.08328454, 22.74460422,  9.84311818, 27.02660765,
#        32.09977106, 27.81315109, 32.21177968, 24.00248578, 25.99770908,
#        31.87235485])

# %%
regr.score(x_train, y_train)
# Out:
# 0.5914278141892433

# %%
regr.score(x_test, y_test)
# Out:
# 0.40959528397842304
